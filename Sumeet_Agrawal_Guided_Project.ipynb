# %% [markdown]
# <a href="https://colab.research.google.com/github/sumeet6510/Movie_data_analysis/blob/main/Sumeet_Agrawal_Guided_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# You have been hired by a rookie movie producer to help him decide what type of movies to produce and which actors to cast. You have to back your recommendations based on thorough analysis of the data he shared with you which has the list of 3000 movies and the corresponding details.
#
# As a data scientist, you have to first explore the data and check its sanity.
#
# Further, you have to answer the following questions:
# 1. Which movie made the highest profit? Who were its producer and director? Identify the actors in that film.
# 2. This data has information about movies made in different languages. Which language has the highest average ROI (return on investment)?
# 3. Find out the unique genres of movies in this dataset.
# 4. Make a table of all the producers and directors of each movie. Find the top 3 producers who have produced movies with the highest average RoI?
# 5. Which actor has acted in the most number of movies? Deep dive into the movies, genres and profits corresponding to this actor.
# 6. Top 3 directors prefer which actors the most?

# %% [markdown]
# # Data Exploration

# %%
#Import package
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
working_dir_path = '/content/drive/MyDrive/Colab Notebooks/Module 1_Phython for Data Science/Week 3/1.13 Exploratory data/'
imdb_df = pd.read_csv(working_dir_path + 'copy_imdb_data.csv')

# %%
imdb_df.head()
# Out:
#    id  ...   revenue
# 0   1  ...  12314651
# 1   2  ...  95149435
# 2   3  ...  13092000
# 3   4  ...  16000000
# 4   5  ...   3923970
#
# [5 rows x 23 columns]

# %%
imdb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   object
# ...

# %%
type(imdb_df.loc[0, 'crew'])
# Out:
# str

# %%
imdb_df.loc[0, 'crew']
# Out:
# '[{\'credit_id\': \'59ac067c92514107af02c8c8\', \'department\': \'Directing\', \'gender\': 0, \'id\': 1449071, \'job\': \'First Assistant Director\', \'name\': \'Kelly Cantley\', \'profile_path\': None}, {\'credit_id\': \'52fe4ee7c3a36847f82afad7\', \'department\': \'Directing\', \'gender\': 2, \'id\': 3227, \'job\': \'Director\', \'name\': \'Steve Pink\', \'profile_path\': \'/myHOgo8mQSCiCAZNGMRdHVr03jr.jpg\'}, {\'credit_id\': \'5524ed25c3a3687ded000d88\', \'department\': \'Writing\', \'gender\': 2, \'id\': 347335, \'job\': \'Writer\', \'name\': \'Josh Heald\', \'profile_path\': \'/pwXJIenrDMrG7t3zNfLvr8w1RGU.jpg\'}, {\'credit_id\': \'5524ed2d925141720c001128\', \'department\': \'Writing\', \'gender\': 2, \'id\': 347335, \'job\': \'Characters\', \'name\': \'Josh Heald\', \'profile_path\': \'/pwXJIenrDMrG7t3zNfLvr8w1RGU.jpg\'}, {\'credit_id\': \'5524ed3d92514166c1004a5d\', \'department\': \'Production\', \'gender\': 2, \'id\': 57822, \'job\': \'Producer\', \'name\': \'Andrew Panay\',
# ...

# %%
print('[1, [2], 3]')
# Out:
# [1, [2], 3]

# %%
from ast import literal_eval
#df['A'] = df['A'].apply(literal_eval)

# %%
literal_eval(imdb_df.loc[0, 'crew'])[0]
# Out:
# {'credit_id': '59ac067c92514107af02c8c8',
#  'department': 'Directing',
#  'gender': 0,
#  'id': 1449071,
#  'job': 'First Assistant Director',
#  'name': 'Kelly Cantley',
#  'profile_path': None}

# %%
type(literal_eval('[1, [2], 3]'))
# Out:
# list

# %%
literal_eval(imdb_df.loc[0, 'cast'])
# Out:
# [{'cast_id': 4,
#   'character': 'Lou',
#   'credit_id': '52fe4ee7c3a36847f82afae7',
#   'gender': 2,
#   'id': 52997,
#   'name': 'Rob Corddry',
#   'order': 0,
#   'profile_path': '/k2zJL0V1nEZuFT08xUdOd3ucfXz.jpg'},
#  {'cast_id': 5,
#   'character': 'Nick',
#   'credit_id': '52fe4ee7c3a36847f82afaeb',
#   'gender': 2,
#   'id': 64342,
#   'name': 'Craig Robinson',
#   'order': 1,
#   'profile_path': '/tVaRMkJXOEVhYxtnnFuhqW0Rjzz.jpg'},
#  {'cast_id': 6,
#   'character': 'Jacob',
#   'credit_id': '52fe4ee7c3a36847f82afaef',
#   'gender': 2,
#   'id': 54729,
#   'name': 'Clark Duke',
#   'order': 2,
#   'profile_path': '/oNzK0umwm5Wn0wyEbOy6TVJCSBn.jpg'},
#  {'cast_id': 7,
#   'character': 'Adam Jr.',
#   'credit_id': '52fe4ee7c3a36847f82afaf3',
#   'gender': 2,
#   'id': 36801,
#   'name': 'Adam Scott',
#   'order': 3,
#   'profile_path': '/5gb65xz8bzd42yjMAl4zwo4cvKw.jpg'},
#  {'cast_id': 8,
#   'character': 'Hot Tub Repairman',
#   'credit_id': '52fe4ee7c3a36847f82afaf7',
# ...

# %%
imdb_df.loc[imdb_df['budget'] ==0 ].head()
# Out:
#     id  ...   revenue
# 4    5  ...   3923970
# 7    8  ...   2586511
# 8    9  ...  34327391
# 11  12  ...  22642033
# 17  18  ...   1234254
#
# [5 rows x 23 columns]

# %%
len(imdb_df.loc[imdb_df['budget']==0])
# Out:
# 812

# %% [markdown]
# # 1. Which movie made the highest profit? Who were its producer and director? Identify the actors in that film.

# %%
imdb_df['profit'] = imdb_df['revenue'] - imdb_df['budget']

# %%
imdb_df.head()
# Out:
#    id                              belongs_to_collection  ...   revenue    profit
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  ...  12314651  -1685349
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  ...  95149435  55149435
# 2   3                                                NaN  ...  13092000   9792000
# 3   4                                                NaN  ...  16000000  14800000
# 4   5                                                NaN  ...   3923970   3923970
#
# [5 rows x 24 columns]

# %%
imdb_df['profit'].max()
# Out:
# 1316249360

# %%
imdb_df[imdb_df['profit']==imdb_df['profit'].max()]
# Out:
#         id  ...      profit
# 1761  1762  ...  1316249360
#
# [1 rows x 24 columns]

# %%
max_profit_movie_df = imdb_df[imdb_df['profit']==imdb_df['profit'].max()]

# %%
max_profit_movie_df
# Out:
#         id  ...      profit
# 1761  1762  ...  1316249360
#
# [1 rows x 24 columns]

# %%
max_profit_movie_df.loc[imdb_df['profit'].idxmax(), 'crew']
# Out:
# '[{\'credit_id\': \'52fe4cc8c3a36847f823e681\', \'department\': \'Production\', \'gender\': 2, \'id\': 12835, \'job\': \'Producer\', \'name\': \'Vin Diesel\', \'profile_path\': \'/7rwSXluNWZAluYMOEWBxkPmckES.jpg\'}, {\'credit_id\': \'52fe4cc8c3a36847f823e687\', \'department\': \'Production\', \'gender\': 2, \'id\': 11874, \'job\': \'Producer\', \'name\': \'Neal H. Moritz\', \'profile_path\': \'/cNcsEYmoS4niCz3UkVAA09dUIob.jpg\'}, {\'credit_id\': \'52fe4cc8c3a36847f823e68d\', \'department\': \'Writing\', \'gender\': 2, \'id\': 58191, \'job\': \'Writer\', \'name\': \'Chris Morgan\', \'profile_path\': \'/dUGxIwFBLrSFLImxjeda1krndMO.jpg\'}, {\'credit_id\': \'52fe4cc8c3a36847f823e693\', \'department\': \'Writing\', \'gender\': 0, \'id\': 8162, \'job\': \'Characters\', \'name\': \'Gary Scott Thompson\', \'profile_path\': \'/e2dMfqFvRsOXgWZ1VToYLmos17y.jpg\'}, {\'credit_id\': \'52fe4cc8c3a36847f823e699\', \'department\': \'Directing\', \'gender\': 2, \'id\': 2127, \'job\': \'Director\', \'n
# ...

# %%
max_profit_movie_df.iloc[0]['crew']
# Out:
# '[{\'credit_id\': \'52fe4cc8c3a36847f823e681\', \'department\': \'Production\', \'gender\': 2, \'id\': 12835, \'job\': \'Producer\', \'name\': \'Vin Diesel\', \'profile_path\': \'/7rwSXluNWZAluYMOEWBxkPmckES.jpg\'}, {\'credit_id\': \'52fe4cc8c3a36847f823e687\', \'department\': \'Production\', \'gender\': 2, \'id\': 11874, \'job\': \'Producer\', \'name\': \'Neal H. Moritz\', \'profile_path\': \'/cNcsEYmoS4niCz3UkVAA09dUIob.jpg\'}, {\'credit_id\': \'52fe4cc8c3a36847f823e68d\', \'department\': \'Writing\', \'gender\': 2, \'id\': 58191, \'job\': \'Writer\', \'name\': \'Chris Morgan\', \'profile_path\': \'/dUGxIwFBLrSFLImxjeda1krndMO.jpg\'}, {\'credit_id\': \'52fe4cc8c3a36847f823e693\', \'department\': \'Writing\', \'gender\': 0, \'id\': 8162, \'job\': \'Characters\', \'name\': \'Gary Scott Thompson\', \'profile_path\': \'/e2dMfqFvRsOXgWZ1VToYLmos17y.jpg\'}, {\'credit_id\': \'52fe4cc8c3a36847f823e699\', \'department\': \'Directing\', \'gender\': 2, \'id\': 2127, \'job\': \'Director\', \'n
# ...

# %%
crew_list = literal_eval(max_profit_movie_df.iloc[0]['crew'])
literal_eval(max_profit_movie_df.iloc[0]['crew'])
# Out:
# [{'credit_id': '52fe4cc8c3a36847f823e681',
#   'department': 'Production',
#   'gender': 2,
#   'id': 12835,
#   'job': 'Producer',
#   'name': 'Vin Diesel',
#   'profile_path': '/7rwSXluNWZAluYMOEWBxkPmckES.jpg'},
#  {'credit_id': '52fe4cc8c3a36847f823e687',
#   'department': 'Production',
#   'gender': 2,
#   'id': 11874,
#   'job': 'Producer',
#   'name': 'Neal H. Moritz',
#   'profile_path': '/cNcsEYmoS4niCz3UkVAA09dUIob.jpg'},
#  {'credit_id': '52fe4cc8c3a36847f823e68d',
#   'department': 'Writing',
#   'gender': 2,
#   'id': 58191,
#   'job': 'Writer',
#   'name': 'Chris Morgan',
#   'profile_path': '/dUGxIwFBLrSFLImxjeda1krndMO.jpg'},
#  {'credit_id': '52fe4cc8c3a36847f823e693',
#   'department': 'Writing',
#   'gender': 0,
#   'id': 8162,
#   'job': 'Characters',
#   'name': 'Gary Scott Thompson',
#   'profile_path': '/e2dMfqFvRsOXgWZ1VToYLmos17y.jpg'},
#  {'credit_id': '52fe4cc8c3a36847f823e699',
#   'department': 'Directing',
#   'gender': 2,
#   'id': 2127,
# ...

# %%
for elem in crew_list:
  if elem['job']=='Producer':
    print(elem['name'], " is a Producer")
  if elem['job']=='Director':
    print(elem['name'], " is a Director")
# Out:
# Vin Diesel  is a Producer
# Neal H. Moritz  is a Producer
# James Wan  is a Director
# Michael Fottrell  is a Producer
# Brandon Birtell  is a Producer

# %%
crew_df = pd.DataFrame(crew_list)

# %%
crew_df.head()
# Out:
#                   credit_id  ...                      profile_path
# 0  52fe4cc8c3a36847f823e681  ...  /7rwSXluNWZAluYMOEWBxkPmckES.jpg
# 1  52fe4cc8c3a36847f823e687  ...  /cNcsEYmoS4niCz3UkVAA09dUIob.jpg
# 2  52fe4cc8c3a36847f823e68d  ...  /dUGxIwFBLrSFLImxjeda1krndMO.jpg
# 3  52fe4cc8c3a36847f823e693  ...  /e2dMfqFvRsOXgWZ1VToYLmos17y.jpg
# 4  52fe4cc8c3a36847f823e699  ...  /d1LSKfzi5J6QngWS7niN1zPJdud.jpg
#
# [5 rows x 7 columns]

# %%
crew_df[(crew_df['job']=='Producer') | (crew_df['job']=='Director')]
# Out:
#                    credit_id  ...                      profile_path
# 0   52fe4cc8c3a36847f823e681  ...  /7rwSXluNWZAluYMOEWBxkPmckES.jpg
# 1   52fe4cc8c3a36847f823e687  ...  /cNcsEYmoS4niCz3UkVAA09dUIob.jpg
# 4   52fe4cc8c3a36847f823e699  ...  /d1LSKfzi5J6QngWS7niN1zPJdud.jpg
# 10  554fa7f2c3a3682254004803  ...                              None
# 11  554fa80292514110bd002aa8  ...                              None
#
# [5 rows x 7 columns]

# %%
crew_df[crew_df['job'].isin(['Producer', 'Director'])]
# Out:
#                    credit_id  ...                      profile_path
# 0   52fe4cc8c3a36847f823e681  ...  /7rwSXluNWZAluYMOEWBxkPmckES.jpg
# 1   52fe4cc8c3a36847f823e687  ...  /cNcsEYmoS4niCz3UkVAA09dUIob.jpg
# 4   52fe4cc8c3a36847f823e699  ...  /d1LSKfzi5J6QngWS7niN1zPJdud.jpg
# 10  554fa7f2c3a3682254004803  ...                              None
# 11  554fa80292514110bd002aa8  ...                              None
#
# [5 rows x 7 columns]

# %%
cast_df = pd.DataFrame(literal_eval(max_profit_movie_df.iloc[0]['cast']))

# %%
cast_df
# Out:
#     cast_id  ...                      profile_path
# 0        17  ...  /7rwSXluNWZAluYMOEWBxkPmckES.jpg
# 1        19  ...  /iqvYezRoEY5k8wnlfHriHQfl5dX.jpg
# 2        18  ...  /kuqFzlYMc2IrsOyPznMd1FroeGq.jpg
# 3        20  ...  /v37VK0MNuRuJOCKPKJcZAJXRA5r.jpg
# 4        28  ...  /a3tyF7QXgeEH0QuEuIzNZZ8oLNS.jpg
# 5        31  ...  /xLfq9wFO6dtYuUK96hbJ8I8EKFw.jpg
# 6        24  ...  /dORwXZWWmDgG66I5i2Fnr27g3fO.jpg
# 7        25  ...  /y22Pb0XAVqC0l7ukzKKtXzPEuHk.jpg
# 8        30  ...  /qq0uXKe3aKaAE04QQ0BvbbFFufF.jpg
# 9        21  ...  /5eGHTV1bLOdajC4Z3pnIdSiptSG.jpg
# 10       27  ...  /yYiJwunH04doOZJgMu7qTZyrRYJ.jpg
# 11       22  ...  /rlnFuNkisPpuypARI7QaGCmOY6V.jpg
# 12       16  ...   /PhWiWgasncGWD9LdbsGcmxkV4r.jpg
# 13       39  ...  /fqt53KEfHWsRDcbV2YAY2lKlKrM.jpg
# 14       38  ...  /34kHAyBaBhq2kUrmhM15paEBuuI.jpg
# 15       15  ...  /41qZZc6vRVm5ZOoXWfEf5NGoIZR.jpg
# 16       23  ...  /c1km2kqasJT9GTISMbBZpp3jbuR.jpg
# ...

# %%
print('The movie which made the highest profit was ', max_profit_movie_df.title.iloc[0])
# Out:
# The movie which made the highest profit was  Furious 7

# %%
print('The producer(s) of this movie: ', crew_df[crew_df['job']=='Producer']['name'].tolist())
# Out:
# The producer(s) of this movie:  ['Vin Diesel', 'Neal H. Moritz', 'Michael Fottrell', 'Brandon Birtell']

# %%
print('The director(s) of this movie: ', crew_df[crew_df['job']=='Director']['name'].tolist())
# Out:
# The director(s) of this movie:  ['James Wan']

# %%
print('The actor(s) of this movie: ', cast_df['name'].tolist())
# Out:
# The actor(s) of this movie:  ['Vin Diesel', 'Paul Walker', 'Dwayne Johnson', 'Michelle Rodriguez', 'Tyrese Gibson', 'Ludacris', 'Jordana Brewster', 'Djimon Hounsou', 'Tony Jaa', 'Ronda Rousey', 'Nathalie Emmanuel', 'Kurt Russell', 'Jason Statham', 'Sung Kang', 'Gal Gadot', 'Lucas Black', 'Elsa Pataky', 'Noel Gugliemi', 'John Brotherton', 'Luke Evans', 'Ali Fazal', 'Miller Kimsey', 'Charlie Kimsey', 'Eden Estrella', 'Gentry White', 'Iggy Azalea', 'Jon Lee Brody', 'Levy Tran', 'Anna Colwell', 'Viktor Hernandez', 'Steve Coulter', 'Robert Pralgo', 'Antwan Mills', 'J.J. Phillips', 'Jorge Ferragut', 'Sara Sohn', 'Benjamin Blankenship', 'D.J. Hapa', 'T-Pain', 'Brian Mahoney', 'Brittney Alger', 'Romeo Santos', 'Jocelin Donahue', 'Stephanie Langston', 'Jorge-Luis Pallo', 'Tego Calderón', 'Nathalie Kelley', 'Shad Moss', 'Don Omar', 'Klement Tinaj', 'Caleb Walker', 'Cody Walker']

# %% [markdown]
# # 2. This data has information about movies made in different languages. Which language has the highest average ROI (return on investment)?

# %%
median_budget_of_sane_data = imdb_df[imdb_df['budget']>1000000]['budget'].median()

# %%
imdb_df.loc[imdb_df['budget']<1000000, 'budget'] = median_budget_of_sane_data

# %%
#imdb_df.replace({'budget': 0}, imdb_df[imdb_df['budget']!=0]['budget'].median(), inplace=True)

# %%
imdb_df['profit'] = imdb_df['revenue'] - imdb_df['budget']
imdb_df['roi'] = 100 * imdb_df['profit']/imdb_df['budget']

# %%
imdb_df.head()
# Out:
#    id                              belongs_to_collection  ...    profit          roi
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  ...  -1685349   -12.038207
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  ...  55149435   137.873588
# 2   3                                                NaN  ...   9792000   296.727273
# 3   4                                                NaN  ...  14800000  1233.333333
# 4   5                                                NaN  ... -15576030   -79.877077
#
# [5 rows x 25 columns]

# %%
imdb_df['roi'].max()
# Out:
# 11623.5147

# %%
imdb_df.original_language.unique()
# Out:
# array(['en', 'hi', 'ko', 'sr', 'fr', 'it', 'nl', 'zh', 'es', 'cs', 'ta',
#        'cn', 'ru', 'tr', 'ja', 'fa', 'sv', 'de', 'te', 'pt', 'mr', 'da',
#        'fi', 'el', 'ur', 'he', 'no', 'ar', 'nb', 'ro', 'vi', 'pl', 'hu',
#        'ml', 'bn', 'id'], dtype=object)

# %%
imdb_df[imdb_df.original_language=='en']['roi'].mean()
# Out:
# 180.64216914276872

# %%
roi_languages_df = imdb_df.groupby('original_language')['roi'].mean().reset_index()

# %%
max_roi_lan = roi_languages_df[roi_languages_df['roi']==roi_languages_df['roi'].max()]

# %%
print('The language with the highest average RoI is :', max_roi_lan['original_language'].iloc[0])
# Out:
# The language with the highest average RoI is : he

# %% [markdown]
# # 3. Find out the unique genres of movies in this dataset.

# %%
imdb_df.head()
# Out:
#    id                              belongs_to_collection  ...    profit          roi
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  ...  -1685349   -12.038207
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  ...  55149435   137.873588
# 2   3                                                NaN  ...   9792000   296.727273
# 3   4                                                NaN  ...  14800000  1233.333333
# 4   5                                                NaN  ... -15576030   -79.877077
#
# [5 rows x 25 columns]

# %%
literal_eval('[1, 2, 3]')
# Out:
# [1, 2, 3]

# %%
imdb_df_no_na_genres = imdb_df[~imdb_df['genres'].isna()]

# %%
len(imdb_df_no_na_genres)
# Out:
# 2993

# %%
imdb_df_no_na_genres.head()
# Out:
#    id                              belongs_to_collection  ...    profit          roi
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  ...  -1685349   -12.038207
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  ...  55149435   137.873588
# 2   3                                                NaN  ...   9792000   296.727273
# 3   4                                                NaN  ...  14800000  1233.333333
# 4   5                                                NaN  ... -15576030   -79.877077
#
# [5 rows x 25 columns]

# %%
len(imdb_df[~imdb_df['genres'].isna()])
# Out:
# 2993

# %%
imdb_df_drop_na_genres = imdb_df['genres'].dropna()

# %%
len(imdb_df_drop_na_genres)
# Out:
# 2993

# %%
imdb_df_drop_na_genres.head()
# Out:
# 0                       [{'id': 35, 'name': 'Comedy'}]
# 1    [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                        [{'id': 18, 'name': 'Drama'}]
# 3    [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4    [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# Name: genres, dtype: object

# %%
imdb_df_no_na_genres.head()
# Out:
#    id                              belongs_to_collection  ...    profit          roi
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  ...  -1685349   -12.038207
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  ...  55149435   137.873588
# 2   3                                                NaN  ...   9792000   296.727273
# 3   4                                                NaN  ...  14800000  1233.333333
# 4   5                                                NaN  ... -15576030   -79.877077
#
# [5 rows x 25 columns]

# %%
imdb_df_no_na_genres['genres_list'] = imdb_df_no_na_genres.apply(lambda row: literal_eval(row['genres']), axis=1)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
imdb_df_no_na_genres.head()
# Out:
#    id  ...                                        genres_list
# 0   1  ...                     [{'id': 35, 'name': 'Comedy'}]
# 1   2  ...  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2   3  ...                      [{'id': 18, 'name': 'Drama'}]
# 3   4  ...  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4   5  ...  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
# [5 rows x 26 columns]

# %%
genres_list = []
for index, row in imdb_df_no_na_genres.iterrows():
  genre_list = imdb_df_no_na_genres.loc[index, 'genres_list']
  for elem in genre_list:
    genres_list.append(elem['name'])

# %%
genres_list[0:5]
# Out:
# ['Comedy', 'Comedy', 'Drama', 'Family', 'Romance']

# %%
set(genres_list)
# Out:
# {'Action',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Crime',
#  'Documentary',
#  'Drama',
#  'Family',
#  'Fantasy',
#  'Foreign',
#  'History',
#  'Horror',
#  'Music',
#  'Mystery',
#  'Romance',
#  'Science Fiction',
#  'TV Movie',
#  'Thriller',
#  'War',
#  'Western'}

# %%
genres_df = pd.DataFrame()
for index, row in imdb_df_no_na_genres.iterrows():
  genre_list = imdb_df_no_na_genres.loc[index, 'genres_list']
  genres_df = genres_df.append(pd.DataFrame(genre_list), ignore_index=True)

# %%
genres_df.head()
# Out:
#       id     name
# 0     35   Comedy
# 1     35   Comedy
# 2     18    Drama
# 3  10751   Family
# 4  10749  Romance

# %%
genres_df.drop_duplicates()
# Out:
#          id             name
# 0        35           Comedy
# 2        18            Drama
# 3     10751           Family
# 4     10749          Romance
# 6        53         Thriller
# 8        28           Action
# 10       16        Animation
# 11       12        Adventure
# 13       27           Horror
# 15       99      Documentary
# 18    10402            Music
# 27       80            Crime
# 30      878  Science Fiction
# 31     9648          Mystery
# 53    10769          Foreign
# 77       14          Fantasy
# 95    10752              War
# 96       37          Western
# 220      36          History
# 4226  10770         TV Movie

# %% [markdown]
# # 4. Make a table of all the producers and directors of each movie. Find the top 3 producers who have produced movies with the highest average RoI?

# %%
movie producers directors

movie1 [p1, p2] [d1, d2]
movie2 [p3, p4] [d3, d4]

movie producers roi

movie1 p1 12
movie1 p2 13
movie2 p3 14
movie2 p4 15

# %%
producer   movies            average_roi
p1.    [m1, m2, m3]    avg_roi(m1, m2, m3)
p2     [m2, m4, m5]    avg_roi(m2, m4, m5)

# %%
imdb_df.head()
# Out:
#    id                              belongs_to_collection  ...    profit          roi
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  ...  -1685349   -12.038207
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  ...  55149435   137.873588
# 2   3                                                NaN  ...   9792000   296.727273
# 3   4                                                NaN  ...  14800000  1233.333333
# 4   5                                                NaN  ... -15576030   -79.877077
#
# [5 rows x 25 columns]

# %%
imdb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   object
# ...

# %%
imdb_df_no_na_crew = imdb_df[~imdb_df['crew'].isna()]

# %%
len(imdb_df_no_na_crew)
# Out:
# 2984

# %%
def get_producers_and_directors(string_rep_of_crew_list):
  try:
    crew_list = literal_eval(string_rep_of_crew_list)
    producer_list = []
    director_list = []
    for elem in crew_list:
      if elem['job']=='Producer':
        producer_list.append(elem['name'])
      if elem['job']=='Director':
        director_list.append(elem['name'])
    return producer_list, director_list
  except:
    return [], []

# %%
get_producers_and_directors(imdb_df_no_na_crew.loc[1, 'crew'])
# Out:
# (['Whitney Houston', 'Mario Iscovich', 'Debra Martin Chase'],
#  ['Garry Marshall'])

# %%
imdb_df[['producers', 'directors']] = imdb_df.apply(lambda s: get_producers_and_directors(s['crew']), axis=1, result_type="expand")
#imdb_df[['pnd']] = imdb_df.apply(lambda s: get_producers_and_directors(s['crew']), axis=1)

# %%
imdb_df.head()
# Out:
#    id  ...                                                pnd
# 0   1  ...                     ([Andrew Panay], [Steve Pink])
# 1   2  ...  ([Whitney Houston, Mario Iscovich, Debra Marti...
# 2   3  ...  ([David Lancaster, Michel Litvak, Jason Blum, ...
# 3   4  ...                     ([Sujoy Ghosh], [Sujoy Ghosh])
# 4   5  ...                             ([], [Jong-seok Yoon])
#
# [5 rows x 28 columns]

# %%
{
    'p1':{'movies':['m1, m2, m3'], 'avg_roi':23},
 'p2':{}

}

# %%
imdb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   object
# ...

# %%
producer_dict = {}
for index, row in imdb_df.iterrows():
  for producer in row['producers']:
    if producer not in producer_dict.keys():
      # add producer in dict
      producer_dict[producer] = [row['roi']]
    else:
      # update the movie for this producer
      value = producer_dict[producer]
      value.append(row['roi'])
      producer_dict[producer] = value

# %%
#data = {'row_1': [3, 2, 1, 0], 'row_2': ['a', 'b', 'c', 'd']}
pd.DataFrame.from_dict(producer_dict, orient='index').mean(axis=1).reset_index().rename(columns={'index':'producer', 0:'average_roi'}).sort_values('average_roi', ascending=False)
# Out:
#                 producer  average_roi
# 2635       Michael White  9307.693250
# 1526       Gregg Hoffman  8559.305750
# 3205      Nelson Greaves  6188.209000
# 2842    Howard G. Minsky  6100.000000
# 1264      Norman Spencer  5458.946615
# ...                  ...          ...
# 1804     Arthur H. Nadel   -99.999964
# 1805        Lou Scheimer   -99.999964
# 1970          Elia Kazan   -99.999974
# 601    Pushpa Kandaswamy   -99.999985
# 2541  Erich von Stroheim   -99.999995
#
# [3546 rows x 2 columns]

# %% [markdown]
# # 5. Which actor has acted in the most number of movies? Deep dive into the movies, genres and profits corresponding to this actor.

# %% [markdown]
# # 6. Top 3 directors prefer which actors the most?
